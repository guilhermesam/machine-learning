# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', 21)

# %%
df = pd.read_csv('../data/customer_churn/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
used_columns = ['gender', 'SeniorCitizen', 'Dependents', 'tenure']

# %%
df = df[used_columns]

# %%
# translating values
gender = {
    'Male': 0,
    'Female': 1
}

dependents = {
    'No': 0,
    'Yes': 1
}

# %%
df = df.replace({'gender': gender, 'Dependents': dependents})

# %%
df
# Out:
#       gender  SeniorCitizen  Dependents  tenure
# 0          1              0           0       1
# 1          0              0           0      34
# 2          0              0           0       2
# 3          0              0           0      45
# 4          1              0           0       2
# ...      ...            ...         ...     ...
# 7038       0              0           1      24
# 7039       1              0           1      72
# 7040       1              0           1      11
# 7041       0              1           0       4
# 7042       0              0           0      66
#
# [7043 rows x 4 columns]

# %%
df.to_csv('customer_churn_processed.csv')

# %%
np.savetxt('customer_churn_processed.txt', df.values, fmt='%d')

# %%
two_dimension_df = pd.read_csv('../data/customer_churn/WA_Fn-UseC_-Telco-Customer-Churn.csv')[['tenure', 'TotalCharges']]

# %%
def find_nullable_values(string):
    return not bool(string.strip())

# %%
null_values_index = two_dimension_df[two_dimension_df['TotalCharges'].apply(convert)].index
two_dimension_df.drop(null_values_index, inplace=True)

# %%
two_dimension_df['TotalCharges'] = two_dimension_df['TotalCharges'].apply(lambda x: float(x))

# %%
np.savetxt('../data/customer_churn/two_dimension_df.txt', two_dimension_df.values)
